# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
apt_filepath = "../python_coursera/train_t.xlsx"

apt_data = pd.read_excel(apt_filepath)

apt_data.head()
# Out:
#    id  timestamp  площадь  жилая площадь  этаж  макс этажи  \
# 0   1 2011-08-20       43           27.0   4.0         NaN
# 1   2 2011-08-23       34           19.0   3.0         NaN
# 2   3 2011-08-27       43           29.0   2.0         NaN
# 3   4 2011-09-01       89           50.0   9.0         NaN
# 4   5 2011-09-05       77           77.0   4.0         NaN
#
#    из чего изготовлен  год постройки  число комнат  площадь кухни  ...  \
# 0                 NaN            NaN           NaN            NaN  ...
# 1                 NaN            NaN           NaN            NaN  ...
# 2                 NaN            NaN           NaN            NaN  ...
# 3                 NaN            NaN           NaN            NaN  ...
# 4                 NaN            NaN           NaN            NaN  ...
#
#    кол-во больничных коек на райоене кол-во больниц на районе  \
# 0                              240.0                        1
# 1                              229.0                        1
# 2                             1183.0                        1
# 3                                NaN                        1
# 4                              562.0                        4
#
#   число университетов в ТОП 20 университетов москвы  \
# 0                                                 0
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 2
#
#    кол-во спортивных объектов на районе  \
# 0                                     7
# 1                                     6
# 2                                     5
# 3                                    17
# 4                                    25
#
#    кол-во школ допольнительного обучения на районе  \
# 0                                                3
# 1                                                1
# 2                                                1
# 3                                                6
# 4                                                2
#
#    есть ли культурный объект, входящий ТОП 25 достопримечательностей Москвы  \
# 0                                                 no
# 1                                                yes
# 2                                                 no
# 3                                                 no
# 4                                                 no
#
#    кол-во культурных объектов, входящих в ТОП 25 объектов Москвы  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Кол-во торговых центров на районе  Кол-во офисов на районе  цена_продажа
# 0                                 16                        1       5850000
# 1                                  3                        0       6000000
# 2                                  0                        1       5700000
# 3                                 11                        4      13100000
# 4                                 10                       93      16331452
#
# [5 rows x 34 columns]

# %%
sns.distplot(apt_data['цена_продажа']/1000)

# %%
print("Skewness: %f" % apt_data['цена_продажа'].skew()) # сильная положительная ассимметрия 
print("Kurtosis: %f" % apt_data['цена_продажа'].kurt()) # острый пик, т.е. большинство значений лежит в узком диапазоне
# Out:
# Skewness: 4.514246
# Kurtosis: 47.259437

# %%
apt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24997 entries, 0 to 24996
# Data columns (total 34 columns):
# id                                                                          24997 non-null int64
# timestamp                                                                   24997 non-null datetime64[ns]
# площадь                                                                     24997 non-null int64
# жилая площадь                                                               19873 non-null float64
# этаж                                                                        24830 non-null float64
# макс этажи                                                                  15425 non-null float64
# из чего изготовлен                                                          15425 non-null float64
# год постройки                                                               12530 non-null float64
# число комнат                                                                15425 non-null float64
# площадь кухни                                                               15425 non-null float64
# состояние жилья                                                             12202 non-null float64
# тип жилья                                                                   24997 non-null object
# район                                                                       24997 non-null object
# площадь района                                                              24997 non-null float64
# чисо жителей                                                                24997 non-null int64
# площадь зеленой зоны                                                        24997 non-null float64
# площадь индустриальной зоны                                                 24997 non-null float64
# кол-во дошкольников                                                         24997 non-null int64
# вместимость дет.садов                                                       19835 non-null float64
# кол-во дет.садов на районе                                                  24997 non-null int64
# кол-во школьников                                                           24997 non-null int64
# вместимость школ                                                            19837 non-null float64
# кол-во школ на районе                                                       24997 non-null int64
# число школ в рейтинге ТОП 20 школ москвы                                    24997 non-null int64
# кол-во больничных коек на райоене                                           13293 non-null float64
# кол-во больниц на районе                                                    24997 non-null int64
# число университетов в ТОП 20 университетов москвы                           24997 non-null int64
# кол-во спортивных объектов на районе                                        24997 non-null int64
# кол-во школ допольнительного обучения на районе                             24997 non-null int64
# есть ли культурный объект, входящий ТОП 25 достопримечательностей Москвы    24997 non-null object
# кол-во культурных объектов, входящих в ТОП 25 объектов Москвы               24997 non-null int64
# Кол-во торговых центров на районе                                           24997 non-null int64
# Кол-во офисов на районе                                                     24997 non-null int64
# цена_продажа                                                                24997 non-null int64
# dtypes: datetime64[ns](1), float64(14), int64(16), object(3)
# memory usage: 6.5+ MB

# %%
var = 'площадь'
data = pd.concat([apt_data['цена_продажа'], apt_data[var]], axis=1)
data.plot.scatter(x=var, y='цена_продажа')

# %% [markdown]
# Очевидно, есть outlier

# %%
var = 'этаж'
data = pd.concat([apt_data['цена_продажа'], apt_data[var]], axis=1)
data.plot.scatter(x=var, y='цена_продажа');

# %% [markdown]
# Аналогично, есть outlier.

# %%
ax = apt_data.boxplot('цена_продажа', by='тип жилья')
ax.set_ylim([0, 20000000])
# Out:
# (0, 20000000)

# %% [markdown]
# Заметим, что что средняя цена жилья типа "investment" дороже, чем "onweroccupier"

# %%
most_expensive = apt_data[{'район', 'цена_продажа'}].nlargest(20 ,'цена_продажа')
most_expensive.groupby('район')['цена_продажа'].count().sort_values(ascending=False)
# Out:
# район
# Hamovniki                4
# Ramenki                  3
# Taganskoe                2
# Tverskoe                 1
# Teplyj Stan              1
# Prospekt Vernadskogo     1
# Presnenskoe              1
# Pokrovskoe Streshnevo    1
# Obruchevskoe             1
# Mar'ina Roshha           1
# Lomonosovskoe            1
# Horoshevskoe             1
# Donskoe                  1
# Arbat                    1
# Name: цена_продажа, dtype: int64

# %% [markdown]
# Самая дорогая недвижимость – в районе Хамовники, Раменки и на Таганке.

# %%
var = 'площадь зеленой зоны'
data = pd.concat([apt_data['цена_продажа'], apt_data[var]], axis=1)
data.plot.scatter(x=var, y='цена_продажа')

# %% [markdown]
# Видим, что цена недвижимости, где площадь зеленой зоны составляет 0-0.2, выше, чем там, где эта площадь больше.
# Как правило, чем ближе к центру, тем выше цена, а в центре города зеленых зон обычно меньше.

# %%
var = 'площадь индустриальной зоны'
data = pd.concat([apt_data['цена_продажа'], apt_data[var]], axis=1)
data.plot.scatter(x=var, y='цена_продажа')

# %% [markdown]
# Похожая картина с индустриальными зонами.

# %%
nvars = ['кол-во дет.садов на районе','площадь зеленой зоны','площадь индустриальной зоны','число школ в рейтинге ТОП 20 школ москвы',
         'кол-во больниц на районе','кол-во школ на районе', 'число университетов в ТОП 20 университетов москвы', 'кол-во спортивных объектов на районе',
         'кол-во школ допольнительного обучения на районе', 'кол-во культурных объектов, входящих в ТОП 25 объектов Москвы', 'Кол-во торговых центров на районе', 'Кол-во офисов на районе']
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16, 12))
for i,feat in enumerate(nvars):
    ax = axes[int(i / 4), i % 4]
    sns.scatterplot(x=feat, y='цена_продажа', data=apt_data, ax=ax)
    ax.set_ylabel('')
    ax.set_xlabel(feat, fontsize=12)

# %%
apt_data['из чего изготовлен'].unique()
sns.boxplot(x='из чего изготовлен', y='цена_продажа', data=apt_data)
plt.ylim(0,20000000)
# Out:
# (0, 20000000)

# %% [markdown]
# Можем сделать вывод, что различие в цене недвижимости в зависимсти от материала дома не является статистически значимым.

# %%
sns.boxplot(x='есть ли культурный объект, входящий ТОП 25 достопримечательностей Москвы', y = 'цена_продажа', data=apt_data)
plt.ylim(0,20000000)
# Out:
# (0, 20000000)

# %%
df_train = apt_data.drop('timestamp', axis = 1)
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(15)
# Out:
#                                    Total   Percent
# состояние жилья                    12795  0.511861
# год постройки                      12467  0.498740
# кол-во больничных коек на райоене  11704  0.468216
# макс этажи                          9572  0.382926
# из чего изготовлен                  9572  0.382926
# число комнат                        9572  0.382926
# площадь кухни                       9572  0.382926
# вместимость дет.садов               5162  0.206505
# вместимость школ                    5160  0.206425
# жилая площадь                       5124  0.204985
# этаж                                 167  0.006681
# район                                  0  0.000000
# площадь района                         0  0.000000
# цена_продажа                           0  0.000000
# тип жилья                              0  0.000000

# %% [markdown]
# Удалим из датасета переменные, которые содержат более 20% пропусков. Мы это можем сделать более или менее безболезненно,
# так как эти переменные коррелируют с другими, которые содержат меньше пропусков. Например, "число комнат", "жилая площадь"
# и "площадь кухни" коррелируют с "площадью", что привело бы к проблеме мультиколлинеарности при построении модели, поэтому будет вполне
# достаточно, если мы учтем только "площадь". Аналогично, избавляемся от переменных "кол-во больничных коек на райоене", "вместимость дет.садов",
# "вместимость школ", так как они коррелируют с числом жителей в районе. "Состояние жилья" и "год постройки"

# %%
df_train['состояние жилья'].unique()
# Out:
# array([nan,  3.,  1.,  2.,  4., 33.])

# %%
sns.scatterplot(x = 'состояние жилья',y='цена_продажа', data = apt_data)

# %% [markdown]
# Состояние жилья на первый взгляд важная переменная, однако она содержит слишком много пропусков. К тому же, не понятно,
# что значат уровни 1,2,3,4,33 - нет очевидной зависимости между состоянияем жилья и ценой.

# %%
sns.scatterplot(x = 'год постройки',y='цена_продажа', data = apt_data)
#apt_data['год постройки'].hist()

# %% [markdown]
# Год постройки не сильно различается, он почти не влияет на цену и содержит много пропусков, поэтому отбрасываем эту переменную.

# %%
df_train = df_train.drop((missing_data[missing_data['Percent'] > 0.2]).index,1)

# %%
df_train.columns
# Out:
# Index(['id', 'площадь', 'этаж', 'тип жилья', 'район', 'площадь района',
#        'чисо жителей', 'площадь зеленой зоны', 'площадь индустриальной зоны',
#        'кол-во дошкольников', 'кол-во дет.садов на районе',
#        'кол-во школьников', 'кол-во школ на районе',
#        'число школ в рейтинге ТОП 20 школ москвы', 'кол-во больниц на районе',
#        'число университетов в ТОП 20 университетов москвы',
#        'кол-во спортивных объектов на районе',
#        'кол-во школ допольнительного обучения на районе',
#        'есть ли культурный объект, входящий ТОП 25 достопримечательностей Москвы',
#        'кол-во культурных объектов, входящих в ТОП 25 объектов Москвы',
#        'Кол-во торговых центров на районе', 'Кол-во офисов на районе',
#        'цена_продажа'],
#       dtype='object')

# %%
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(corrmat, vmax=.8, square=True, annot=True, fmt='.2f', annot_kws={'size': 9})

# %% [markdown]
# Выберем переменные, которые больше всего влияют на цену и не сильно коррелируют между собой.

# %%
cols = ['тип жилья','площадь','чисо жителей','этаж', 'число университетов в ТОП 20 университетов москвы', 
        'кол-во школ допольнительного обучения на районе',
        'есть ли культурный объект, входящий ТОП 25 достопримечательностей Москвы',
        'кол-во спортивных объектов на районе', 'кол-во больниц на районе', 'Кол-во торговых центров на районе',
        'цена_продажа']

# %%
df_train[cols].isnull().sum().sort_values(ascending=False)
# Out:
# этаж                                                                        167
# цена_продажа                                                                  0
# Кол-во торговых центров на районе                                             0
# кол-во больниц на районе                                                      0
# кол-во спортивных объектов на районе                                          0
# есть ли культурный объект, входящий ТОП 25 достопримечательностей Москвы      0
# кол-во школ допольнительного обучения на районе                               0
# число университетов в ТОП 20 университетов москвы                             0
# чисо жителей                                                                  0
# площадь                                                                       0
# тип жилья                                                                     0
# dtype: int64

# %%
df_good_vars = df_train[cols]
df_good_vars = df_good_vars.drop(df_good_vars.loc[df_good_vars['этаж'].isnull()].index)

# %%
df_good_vars.shape
# Out:
# (24830, 11)

# %%
df_good_vars.isnull().sum()
# Out:
# тип жилья                                                                   0
# площадь                                                                     0
# чисо жителей                                                                0
# этаж                                                                        0
# число университетов в ТОП 20 университетов москвы                           0
# кол-во школ допольнительного обучения на районе                             0
# есть ли культурный объект, входящий ТОП 25 достопримечательностей Москвы    0
# кол-во спортивных объектов на районе                                        0
# кол-во больниц на районе                                                    0
# Кол-во торговых центров на районе                                           0
# цена_продажа                                                                0
# dtype: int64

# %% [markdown]
# Удалим выбросы из датасета

# %%
Q1 = df_good_vars.quantile(0.25)
Q3 = df_good_vars.quantile(0.75)
IQR = Q3 - Q1

df_clean = df_good_vars[~((df_good_vars < (Q1 - 1.5 * IQR)) |(df_good_vars > (Q3 + 1.5 * IQR))).any(axis=1)]
df_clean.shape
# Out:
# (19800, 11)

# %% [markdown]
# Рассмотрим распределение цены.

# %%
sns.distplot(df_clean['цена_продажа'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_clean['цена_продажа'], plot=plt)

# %% [markdown]
# Рассомтрим ассиметрию и стандартное отклонение переменнных.

# %%
statis = pd.DataFrame((df_clean.skew().sort_values(ascending=False)), columns = ['skew'])
statis['Std'] = df_clean.std()
statis[statis['skew'] > 1]
# Out:
# Empty DataFrame
# Columns: [skew, Std]
# Index: []

# %%
statis = pd.DataFrame((df_clean.std().sort_values(ascending=False)), columns = ['std'])
statis[statis['std'] > 30]
# Out:
#                        std
# цена_продажа  2.504024e+06
# чисо жителей  5.547932e+04

# %% [markdown]
# Стандартизируем переменную "число жителей".

# %%
df_clean[['чисо жителей']] = StandardScaler().fit_transform(df_clean[['чисо жителей']])
df_clean
# Out:
#            тип жилья  площадь  чисо жителей  этаж  \
# 1         Investment       34      0.662541   3.0
# 2         Investment       43      0.416605   2.0
# 3         Investment       89      1.800309   9.0
# 5         Investment       67     -0.627288  14.0
# 6         Investment       25     -0.381965  10.0
# ...              ...      ...           ...   ...
# 24992     Investment       37      0.401067  16.0
# 24993  OwnerOccupier       72     -1.023409   2.0
# 24994  OwnerOccupier       40     -1.166331   1.0
# 24995     Investment       51      0.003864   8.0
# 24996  OwnerOccupier       82     -1.244506  12.0
#
#        число университетов в ТОП 20 университетов москвы  \
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 5                                                      0
# 6                                                      0
# ...                                                  ...
# 24992                                                  0
# 24993                                                  0
# 24994                                                  0
# 24995                                                  0
# 24996                                                  0
#
#        кол-во школ допольнительного обучения на районе  \
# 1                                                    1
# 2                                                    1
# 3                                                    6
# 5                                                    0
# 6                                                    6
# ...                                                ...
# 24992                                                2
# 24993                                                3
# 24994                                                1
# 24995                                                2
# 24996                                                0
#
#       есть ли культурный объект, входящий ТОП 25 достопримечательностей Москвы  \
# 1                                                    yes
# 2                                                     no
# 3                                                     no
# 5                                                     no
# 6                                                     no
# ...                                                  ...
# 24992                                                 no
# 24993                                                 no
# 24994                                                 no
# 24995                                                 no
# 24996                                                 no
#
#        кол-во спортивных объектов на районе  кол-во больниц на районе  \
# 1                                         6                         1
# 2                                         5                         1
# 3                                        17                         1
# 5                                         7                         0
# 6                                        17                         3
# ...                                     ...                       ...
# 24992                                     3                         2
# 24993                                     3                         0
# 24994                                     0                         0
# 24995                                     3                         0
# 24996                                     1                         0
#
#        Кол-во торговых центров на районе  цена_продажа
# 1                                      3       6000000
# 2                                      0       5700000
# 3                                     11      13100000
# 5                                      6       9100000
# 6                                      6       5500000
# ...                                  ...           ...
# 24992                                  5       6600000
# 24993                                  2       8590436
# 24994                                  0       4295979
# 24995                                  5       8100000
# 24996                                  0       8109738
#
# [19800 rows x 11 columns]

# %%
#Box Cox transformation
array_price = np.asarray(df_clean['цена_продажа'].values)

# transform values
price_boxcox = stats.boxcox(array_price)[0] #this 0 will return the array with transformed data
df_clean['BoxCoxPrice'] = price_boxcox 
#For future reference we print the lambda of the BoxCox transformation, we will need this to do the inverse 
#this one will return teh lambda used to trnasoform the data, used later for inverser boxcox
lambda_boxcox = stats.boxcox(array_price)[1]
print(lambda_boxcox)

print(df_clean['BoxCoxPrice'].skew())
# Out:
# 0.7655600551147644
# -0.0020580912035853

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

X = df_clean.drop(['цена_продажа','BoxCoxPrice'], axis=1)
y = df_clean['BoxCoxPrice']
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

s = (df_clean.dtypes == 'object')
object_cols = list(s[s].index)

OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
OH_cols_train = pd.DataFrame(OH_encoder.fit_transform(X_train[object_cols]))
OH_cols_valid = pd.DataFrame(OH_encoder.transform(X_valid[object_cols]))

# One-hot encoding removed index; put it back
OH_cols_train.index = X_train.index
OH_cols_valid.index = X_valid.index

# Remove categorical columns (will replace with one-hot encoding)
num_df_train = X_train.drop(object_cols, axis=1)
num_X_valid = X_valid.drop(object_cols, axis=1)

# Add one-hot encoded columns to numerical features
OH_X_train = pd.concat([num_df_train, OH_cols_train], axis=1)
OH_X_valid = pd.concat([num_X_valid, OH_cols_valid], axis=1)

# %% [markdown]
# Моделирование с XGBoost

# %%
import xgboost as xgb 
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error
from scipy.special import inv_boxcox

with warnings.catch_warnings():
    warnings.simplefilter("ignore")

# %%
XGBoost = XGBRegressor()

#Parameters for XG Boost
grid_para_xgboost = [{
        'learning_rate': [0.01,0.1,0.2],
        #'min_child_weight': [1,3, 5,7 ,10],
        #'gamma': [0.25,0.5, 1, 1.5, 2, 5],
        #'subsample': [0.4,0.6, 0.8, 1.0],
        #'colsample_bytree': [0.4,0.6, 0.8, 1.0],
        'max_depth': [3,4,5]
        }]

#Once parameters are selected we pass them to the model
grid_search_xgboost = GridSearchCV(XGBoost, grid_para_xgboost, cv=10)

#we fit the model
# %time grid_search_xgboost.fit(OH_X_train, y_train)
# Out:
# [21:19:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:19:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:19:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:19:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:20:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:20:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:20:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:20:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:21:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:21:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:21:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:22:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:22:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:22:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:23:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:23:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:24:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:25:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:25:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:26:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:26:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:27:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:27:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:28:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:28:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:29:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:29:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:30:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:30:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:31:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:31:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:31:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:32:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:32:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:32:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:33:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:34:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:35:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:36:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:37:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:38:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:39:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:40:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:41:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:42:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:42:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:42:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:43:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:43:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:44:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:44:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:44:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:45:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:45:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:45:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:46:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:46:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:46:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:47:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:47:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:47:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:47:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:48:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:48:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:49:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:49:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:49:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:50:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:50:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:50:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:51:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:51:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:52:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:52:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:53:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:53:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:53:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:54:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:54:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# CPU times: user 31min 21s, sys: 35.1 s, total: 31min 57s
# Wall time: 35min 44s
# GridSearchCV(cv=10, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'learning_rate': [0.01, 0.1, 0.2],
#                           'max_depth': [3, 4, 5]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
XGBoost.set_params(**grid_search_xgboost.best_params_)

print(grid_search_xgboost.best_params_)

print(grid_search_xgboost.best_score_)
# Out:
# {'learning_rate': 0.2, 'max_depth': 5}
# 0.3932390333504192

# %%
#xgboost = XGBRegressor(learning_rate= 0.2)
xgboost = XGBRegressor()
xgboost_model = xgboost.fit(OH_X_train, y_train)

xgboost_train_pred = pd.DataFrame(inv_boxcox(xgboost_model.predict(OH_X_train),0.7722795403566581), columns=['BoxCoxPrice'])
xgboost_test_pred = pd.DataFrame(inv_boxcox(xgboost_model.predict(OH_X_valid),0.7722795403566581), columns=['BoxCoxPrice'])


xgboost_train = np.sqrt(mean_absolute_error((inv_boxcox(y_train,0.7722795403566581)), xgboost_train_pred))
xgboost_test = np.sqrt(mean_absolute_error((inv_boxcox(y_valid,0.7722795403566581)), xgboost_test_pred))

print("MAE for train data: %.1f" % round(xgboost_train, 1))
print("MAE for test data: %.1f" % round(xgboost_test, 1))
# Out:
# [22:29:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# MAE for train data: 1055.5
# MAE for test data: 1062.5

# %% [markdown]
# Моделирование с Random forest.

# %%
forest = RandomForestRegressor(n_estimators=500,
                               max_features = 'sqrt',
                                oob_score=True,
                                min_samples_leaf=5, 
                               min_samples_split= 8)

forest_model = forest.fit(OH_X_train, y_train)

rf_y_train_pred = pd.DataFrame(inv_boxcox(forest_model.predict(OH_X_train),0.7722795403566581), columns=['BoxCoxPrice'])
rf_y_test_pred = pd.DataFrame(inv_boxcox(forest_model.predict(OH_X_valid),0.7722795403566581), columns=['BoxCoxPrice'])

rmse_rf_train = np.sqrt(mean_absolute_error((inv_boxcox(y_train,0.7722795403566581)), rf_y_train_pred))
rmse_rf_test = np.sqrt(mean_absolute_error((inv_boxcox(y_valid,0.7722795403566581)), rf_y_test_pred))

print("MAE for train data: %.1f" % round(rmse_rf_train, 1))
print("MAE for test data: %.1f" % round(rmse_rf_test, 1))
# Out:
# MAE for train data: 967.2
# MAE for test data: 1036.7

# %% [markdown]
# Рассмотрим другие модели.

# %% [markdown]
# Загружаем тестовый датасет и прогнозируем цену.

# %%
apt_test_filepath = "../python_coursera/test_t.xlsx"

apt_test_data = pd.read_excel(apt_test_filepath)

intersection_cols = df_good_vars.columns & apt_test_data.columns
apt_test_data = apt_test_data[intersection_cols]

apt_test_data.isnull().sum().sort_values(ascending=False)
# Out:
# Кол-во торговых центров на районе                                           0
# кол-во больниц на районе                                                    0
# кол-во спортивных объектов на районе                                        0
# есть ли культурный объект, входящий ТОП 25 достопримечательностей Москвы    0
# кол-во школ допольнительного обучения на районе                             0
# число университетов в ТОП 20 университетов москвы                           0
# этаж                                                                        0
# чисо жителей                                                                0
# площадь                                                                     0
# тип жилья                                                                   0
# dtype: int64

# %%
apt_test_data[['чисо жителей']] = StandardScaler().fit_transform(apt_test_data[['чисо жителей']])

OH_encoder = OneHotEncoder(handle_unknown='ignore', sparse=False)
OH_cols_test = pd.DataFrame(OH_encoder.fit_transform(apt_test_data[object_cols]))
OH_cols_test.index = apt_test_data.index
num_X_test = apt_test_data.drop(object_cols, axis=1)
OH_X_test = pd.concat([num_X_test, OH_cols_test], axis=1)

# %% [markdown]
# Прогнозируем цену.

# %%
price_pred = inv_boxcox(forest_model.predict(OH_X_test),0.7722795403566581)
#pd.DataFrame(price_pred).to_csv("path/to/file.csv")

# %%
price_pred
# Out:
# array([4178846.22622293, 5442555.13941862, 6490443.52612303, ...,
#        4168138.78712065, 7036980.26414562, 5121953.59741314])
