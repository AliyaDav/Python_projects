# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# %%
# get stock info
msft.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
# ...

# %%
import pandas as pd

df = pd.read_excel('US_stocks.xlsx', usecols=lambda x: 'Unnamed' not in x,)
print (df)
# Out:
#    Symbol                                  Name            industry  \
# 0      CX                 CEMEX, S.A.B. de C.V.     basic materials
# 1     GGB                           Gerdau S.A.     basic materials
# 2     HMY   Harmony Gold Mining Company Limited     basic materials
# 3     AUY                      Yamana Gold Inc.     basic materials
# 4     BTG                          B2Gold Corp.     basic materials
# 5    ITUB            Itau Unibanco Holding S.A.          financial
# 6     BAC           Bank of America Corporation          financial
# 7     WFC                 Wells Fargo & Company          financial
# 8       C                        Citigroup Inc.          financial
# 9     BBD                   Banco Bradesco S.A.          financial
# 10   ABEV                            Ambev S.A.  consumer defensive
# 11   BYND                     Beyond Meat, Inc.  consumer defensive
# 12     KO                 The Coca-Cola Company  consumer defensive
# ...

# %%
tickers = df.Symbol.to_list()
tickers[0:5]
# Out:
# ['CX', 'GGB', 'HMY', 'AUY', 'BTG']

# %%
data = pd.DataFrame(columns=tickers)

# Fetch the data

for ticker in tickers:
    data[ticker] = yf.download(tickers,'2020-01-24','2020-04-24')['Adj Close']

# Print first 5 rows of the data
data.head()
# Out:
# [*********************100%***********************]  50 of 50 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    3524             try:
# -> 3525                 value = Series(value)
#    3526             except (ValueError, NotImplementedError, TypeError):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     312
# --> 313                 data = SingleBlockManager(data, index, fastpath=True)
#     314
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1515         if not isinstance(block, Block):
# -> 1516             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1517
# ...

# %%
data = yf.download(tickers[0:5],'2020-01-24','2020-04-24')['Adj Close']
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data.head()
# Out:
#                  AUY       BTG    CX       GGB   HMY
# Date
# 2020-01-23  3.932710  4.210663  4.24  5.300062  3.50
# 2020-01-24  4.042229  4.310442  4.22  5.160324  3.67
# 2020-01-27  4.062141  4.350354  4.15  4.731128  3.56
# 2020-01-28  3.872973  4.160774  4.35  4.810979  3.27
# 2020-01-29  3.962579  4.280509  4.27  4.751091  3.29

# %%
import matplotlib.pyplot as plt

# Plot all the close prices
#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Adjusted Close Price.Basic materials", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)


# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
data = yf.download(tickers[5:10],'2020-01-24','2020-04-24')['Adj Close']

#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.Financial", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data = yf.download(tickers[10:15],'2020-01-24','2020-04-24')['Adj Close']

#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.consumer defensive", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data = yf.download(tickers[15:20],'2020-01-24','2020-04-24')['Adj Close']

#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.Utilities", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data = yf.download(tickers[20:25],'2020-01-24','2020-04-24')['Adj Close']

#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.Energy", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data = yf.download(tickers[25:30],'2020-01-24','2020-04-24')['Adj Close']

#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.Tech", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data = yf.download(tickers[30:35],'2020-01-24','2020-04-24')['Adj Close']

#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.consumer ciclycal", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data.head()
# Out:
#                   AAL        AMD         GE   INO       SNAP
# Date
# 2020-01-23  28.693960  51.709999  11.758324  3.84  19.250000
# 2020-01-24  27.538231  50.349998  11.698383  4.24  19.049999
# 2020-01-27  26.013866  49.259998  11.428651  5.32  18.620001
# 2020-01-28  26.800957  50.529999  11.718363  4.36  18.990000
# 2020-01-29  26.701324  47.509998  12.927162  4.11  19.139999

# %%
data = yf.download(tickers[35:40],'2020-01-24','2020-04-24')['Adj Close']

#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.Real estate", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data = yf.download(tickers[40:45],'2020-01-24','2020-04-24')['Adj Close']

# data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.Health", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data = yf.download(tickers[45:50],'2020-01-24','2020-04-24')['Adj Close']

#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.Comunication", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data = yf.download(tickers[50:55],'2020-01-24','2020-04-24')['Adj Close']

#data.plot(figsize=(10, 7))
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title("Adjusted Close Price.Industrial", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data.tail()
# Out:
#               AAL          BA        DAL    GE   RLLCF
# Date
# 2020-04-17  11.57  154.000000  24.270000  6.84  0.0036
# 2020-04-20  11.06  143.610001  23.639999  6.51  0.0041
# 2020-04-21  11.00  136.330002  23.100000  6.48  0.0052
# 2020-04-22  10.27  134.970001  22.469999  6.43  0.0075
# 2020-04-23  10.25  137.740005  22.480000  6.52  0.0114
